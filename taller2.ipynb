# %% [markdown]
# <a href="https://colab.research.google.com/github/jcamil0/IA-usc/blob/master/taller2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
# import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %%
image = io.imread("/content/drive/MyDrive/Colab Notebooks/GoogleColab/figColores (1).jpg")
img_hsv = cv.cvtColor(image, cv.COLOR_RGB2HSV)

#Primer umbral del color rojo en HSV
umbral_bajo1 = (170,100,100)
umbral_alto1 = (179,255,255)

#Segundo umbral del color rojo en HSV
umbral_bajo2 = (0,100,100)
umbral_alto2 = (10,255,255)

#Se aplica la mascara y se filtra en la original
#Con la mascara 1 si encuentra el color, de lo contraio 0
mask1 = cv.inRange(img_hsv, umbral_bajo1, umbral_alto1)
mask2 = cv.inRange(img_hsv, umbral_bajo2, umbral_alto2)
mask = mask1 + mask2
res = cv.bitwise_and(image, image, mask=mask)

#Se muestran los resultados
plt.subplot(1, 2, 1) # 1 fila, 2 columnas y crea ejes en la posición 1
plt.imshow(mask, cmap="gray")
plt.subplot(1, 2, 2)
plt.imshow(res)
plt.show()

# %%
# Leer imagen.
img = cv2.imread('./figPelotas (1).jpg', cv2.IMREAD_COLOR)
  
# Convertir a escala de grises.
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  
# Desenfocar usando kernel 3 * 3.
gray_blurred = cv2.blur(gray, (3, 3))
  
# Aplique la transformación de Hough en la imagen borrosa.
detected_circles = cv2.HoughCircles(gray_blurred, 
                   cv2.HOUGH_GRADIENT, 1, 20, param1 = 50,
               param2 = 30, minRadius = 1, maxRadius = 40)
  
# Dibujar círculos que se detecten.
if detected_circles is not None:
  
    # Convierta los parámetros del círculo a, byr en números enteros.
    detected_circles = np.uint16(np.around(detected_circles))
  
    for pt in detected_circles[0, :]:
        a, b, r = pt[0], pt[1], pt[2]
  
        # Dibuja la circunferencia del círculo.
        cv2.circle(img, (a, b), r, (0, 255, 0), 2)
  
        # Dibuja un pequeño círculo (de radio 1) para mostrar el centro.
        cv2.circle(img, (a, b), 1, (0, 0, 255), 3)
        cv2.imshow("Detected Circle", img)
        cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2bb3839105f6> in <module>()
#       1 image = io.imread("/content/drive/MyDrive/Colab Notebooks/GoogleColab/figPelotas (1).jpg")
# ----> 2 gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
#       3
#       4 # Convert to grayscale.
#       5 gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
#
# NameError: name 'cv' is not defined

# %%
image = io.imread("/content/drive/MyDrive/Colab Notebooks/GoogleColab/figOjos.jpg")
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

# Convert to grayscale.
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
  
# Blur using 3 * 3 kernel.
gray_blurred = cv.blur(gray, (3, 3))
  
# Apply Hough transform on the blurred image.
detected_circles = cv.HoughCircles(gray_blurred, 
                   cv.HOUGH_GRADIENT, 1, 20, param1 = 50,
               param2 = 40, minRadius = 1, maxRadius = 40)
  
# Draw circles that are detected.
if detected_circles is not None:
  
    # Convert the circle parameters a, b and r to integers.
    detected_circles = np.uint16(np.around(detected_circles))
  
    for pt in detected_circles[0, :]:
        a, b, r = pt[0], pt[1], pt[2]
  
        # Draw the circumference of the circle.
        cv.circle(image, (a, b), r, (0, 255, 0), 2)

    
    #cv2_imshow(image)
    plt.imshow(image)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-99f3831d321e> in <module>()
#       1 image = io.imread("/content/drive/MyDrive/Colab Notebooks/GoogleColab/figPelotas (1).jpg")
# ----> 2 gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
#       3
#       4 # Convert to grayscale.
#       5 gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
#
# NameError: name 'cv' is not defined
